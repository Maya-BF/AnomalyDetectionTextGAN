# %%
# -*- coding: utf-8 -*-
"""
LSTM decoder-encoder

# References
- [1] [Convolutional Neural Networks for Sentence Classification](https://arxiv.org/abs/1408.5882)

@author: Mariem Ben Fadhel
"""
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.utils import plot_model

from keras.layers import Activation, Input, Dense, Dropout
from keras.models import Model
from keras import initializers
from keras import backend as K

class LSTM_DE:
    
    __version__ = '0.0.1'
    
    def __init__(self, n_inputs=3, batch_size=64, features=3234000, hidden_units=100, dropout_rate=None):
        """
        Arguments:
            n_inputs        : Number of inputs to the LSTM
            batch_size      : Size of batch of data
            features        : Number of features is the size of embedding layer output 
                                    (other layer outputs had been padded)
            hidden_units    : Hidden units  (default: 100)
            dropout_rate    : If defined, dropout will be added after embedding layer & concatenation (default: None)
        """
        self.n_inputs        = n_inputs
        self.hidden_units    = hidden_units
        self.dropout_rate    = dropout_rate
        self.batch_size      = batch_size
        self.features        = features
        
    def build_model(self):
        """
        Build the model
        
        Returns:
            Model           : Keras model instance
        """
        input_sequence = Input(shape=(self.max_seq_length,), dtype='int32', name='word_input')
        x = Sequential() 
        x = LSTM(100, activation='relu', input_shape=(64,n_inputs,embeddings_size))
        x = RepeatVector(n_inputs)(x)
        x = LSTM(100, activation='relu', return_sequences=True)(x)
        x = Activation('relu')(x)
        x = TimeDistributed(Dense(1))(x)
        return Model(inputs=word_input, outputs=prediction)
        
        model = Sequential()
        #model.add(LSTM(100, activation='relu', input_shape=(n_in,1)))
        model.add()
        model.add()
        model.add(LSTM(100, activation='relu', return_sequences=True))
        model.add(TimeDistributed(Dense(1)))
        model.compile(optimizer='adam', loss='mse')
        # fit model
        model.fit(sequence, sequence, epochs=300, verbose=0)
        plot_model(model, show_shapes=True, to_file='reconstruct_lstm_autoencoder.png')
