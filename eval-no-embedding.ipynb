# %%
import tensorflow as tf
import numpy as np
import os
import time
import datetime
import helper
from text_cnn import TextCNN
from tensorflow.contrib import learn
import csv
import sys
from sklearn import metrics
import yaml
import pandas as pd
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Parameters
# ==================================================

# Data Parameters
#tf.flags.DEFINE_string("positive_data_file", "./data/rt-polaritydata/rt-polarity.pos", "Data source for the positive data.")
#tf.flags.DEFINE_string("negative_data_file", "./data/rt-polaritydata/rt-polarity.neg", "Data source for the negative data.")

# Eval Parameters
tf.flags.DEFINE_integer("batch_size", 64, "Batch Size (default: 64)") 
#tf.flags.DEFINE_string("checkpoint_dir", "./runs/1547161743/checkpoints/", "Checkpoint directory from training run")
tf.flags.DEFINE_string("checkpoint_dir", "./runs/1548728574/checkpoints/", "Checkpoint directory from training run")

tf.flags.DEFINE_boolean("eval_train", True, "Evaluate on all training data")
tf.flags.DEFINE_integer("embedding_dim", 128, "Dimensionality of character embedding (default: 128)")
tf.flags.DEFINE_integer("num_filters", 128, "Number of filters per filter size (default: 128)")
tf.flags.DEFINE_string("filter_sizes", "3,4,5", "Comma-separated filter sizes (default: '3,4,5')")
tf.flags.DEFINE_boolean("enable_word_embeddings", True, "Enable/disable the word embedding (default: True)")

# Misc Parameters
tf.flags.DEFINE_boolean("allow_soft_placement", True, "Allow device soft device placement")
tf.flags.DEFINE_boolean("log_device_placement", False, "Log placement of ops on devices")


tf.app.flags.DEFINE_string('f', '', 'kernel')
FLAGS = tf.flags.FLAGS
FLAGS(sys.argv)
print("\nParameters:")

for attr, value in sorted(FLAGS.__flags.items()):
    print("{}={}".format(attr.upper(), value))
print("")

#load config file
with open("config.yml", 'r') as ymlfile:
    cfg = yaml.load(ymlfile)


if FLAGS.enable_word_embeddings and cfg['word_embeddings']['default'] is not None:
    embedding_name = cfg['word_embeddings']['default']
    embedding_dimension = cfg['word_embeddings'][embedding_name]['dimension']
else:
    embedding_dimension = FLAGS.embedding_dim
# Out:
# Parameters:
# ALLOW_SOFT_PLACEMENT=<absl.flags._flag.BooleanFlag object at 0x7f83e65782b0>
# BATCH_SIZE=<absl.flags._flag.Flag object at 0x7f83e6574f28>
# CHECKPOINT_DIR=<absl.flags._flag.Flag object at 0x7f83e6574f98>
# EMBEDDING_DIM=<absl.flags._flag.Flag object at 0x7f83e65780f0>
# ENABLE_WORD_EMBEDDINGS=<absl.flags._flag.BooleanFlag object at 0x7f83e65781d0>
# EVAL_TRAIN=<absl.flags._flag.BooleanFlag object at 0x7f83e6569668>
# F=<absl.flags._flag.Flag object at 0x7f83e6578438>
# FILTER_SIZES=<absl.flags._flag.Flag object at 0x7f83e6578240>
# LOG_DEVICE_PLACEMENT=<absl.flags._flag.BooleanFlag object at 0x7f83e6578320>
# NUM_FILTERS=<absl.flags._flag.Flag object at 0x7f83e6578198>

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    if x.ndim == 1:
        x = x.reshape((1, -1))
    max_x = np.max(x, axis=1).reshape((-1, 1))
    exp_x = np.exp(x - max_x)
    return exp_x / np.sum(exp_x, axis=1).reshape((-1, 1))

# %%
datasets = None
# CHANGE THIS: Load data. Load your own data here
dataset_name = cfg["datasets"]["default"]
if FLAGS.eval_train:
    #x_raw, y_test = helper.load_data_and_labels(FLAGS.positive_data_file, FLAGS.negative_data_file)
    if dataset_name == "mrpolarity":
        datasets = helper.get_datasets_mrpolarity(cfg["datasets"][dataset_name]["positive_data_file"]["path"],
                                                        cfg["datasets"][dataset_name]["negative_data_file"]["path"])
    elif dataset_name == "20newsgroup":
        datasets = helper.get_datasets_20newsgroup(subset="test",
                                              categories=cfg["datasets"][dataset_name]["categories"],
                                              shuffle=cfg["datasets"][dataset_name]["shuffle"],
                                              random_state=cfg["datasets"][dataset_name]["random_state"])
    x_raw, y_test = helper.load_data_labels(datasets)
    num_categories = y_test.shape[1]
    y_test = np.argmax(y_test, axis=1)
    
else:
    #x_raw = ["a masterpiece four years in the making", "everything is off."]
    #y_test = [1, 0]
    if dataset_name == "mrpolarity":
        datasets = {"target_names": ['positive_examples', 'negative_examples']}
        x_raw = ["a masterpiece four years in the making", "everything is off."]
        y_test = [1, 0]
        num_categories = 2
    else:
        datasets = {"target_names": ['alt.atheism', 'comp.graphics', 'sci.med', 'soc.religion.christian']}
        x_raw = ["The number of reported cases of gonorrhea in Colorado increased",
                 "I am in the market for a 24-bit graphics card for a PC"]
        y_test = [2, 1]
        num_categories = 4

# Map data into vocabulary
vocab_path = os.path.join(FLAGS.checkpoint_dir, "..", "vocab")
vocab_processor = learn.preprocessing.VocabularyProcessor.restore(vocab_path)
x_test = np.array(list(vocab_processor.transform(x_raw)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/preprocessing/text.py:203: tokenizer (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.

# %%
print("\nEvaluating...\n")

# Evaluation
# ==================================================
checkpoint_file = tf.train.latest_checkpoint(FLAGS.checkpoint_dir)
graph = tf.Graph()
gpu_options=tf.GPUOptions()
gpu_options.allow_growth = True
with graph.as_default():
    session_conf = tf.ConfigProto(
      allow_soft_placement=FLAGS.allow_soft_placement,
      log_device_placement=FLAGS.log_device_placement,
      gpu_options=gpu_options)
    sess = tf.Session(config=session_conf)
    with sess.as_default():
        # Load the saved meta graph and restore variables
        saver = tf.train.import_meta_graph("{}.meta".format(checkpoint_file))
        saver.restore(sess, checkpoint_file)
        
        for op in graph.get_operations():
            print(op.name)
        
        # Get the placeholders from the graph by name
        input_x = graph.get_operation_by_name("input_x").outputs[0]
        input_y = graph.get_operation_by_name("input_y").outputs[0]
        dropout_keep_prob = graph.get_operation_by_name("dropout_keep_prob").outputs[0]

        # Tensors we want to evaluate
        predictions = graph.get_operation_by_name("output/predictions").outputs[0]
        scores = graph.get_operation_by_name("output/scores").outputs[0]
        #embeddings = graph.get_operation_by_name("embedding/embedded_chars").outputs[0]
        pool_convs = graph.get_operation_by_name("pool/h_pool_flat").outputs[0]
        drops = graph.get_operation_by_name("dropout/h_drop/mul").outputs[0]

        # Generate batches for one epoch
        batches = helper.batch_iter(list(x_test), FLAGS.batch_size, 1, shuffle=False)

        # Collect the predictions here
        total_filters = len(FLAGS.filter_sizes.split(',')) * FLAGS.num_filters
        all_predictions = []
        data_out=np.empty([64,3])
        all_probabilities = None
      
        all_scores = np.zeros((FLAGS.batch_size, num_categories))
        #all_embeddings = np.zeros((FLAGS.batch_size, int(input_x.shape[1] * embedding_dimension)))
        all_pool_convs = np.zeros((FLAGS.batch_size, total_filters))
        all_drops = np.zeros((FLAGS.batch_size, total_filters))

        out_dir = os.path.abspath(os.path.join(os.path.curdir, "output5_mrpolarity"))
        if not os.path.exists(out_dir):
            os.makedirs(out_dir)
            
        print("Ready for the run...")    

        for x_test_batch in batches:
            #batch_predictions, batch_scores, batch_embeddings, batch_pool_convs = sess.run([predictions, scores, embeddings, pool_convs], {input_x: x_test_batch, dropout_keep_prob: 1.0})
            batch_predictions, batch_scores, batch_drops, batch_pool_convs = sess.run([predictions, scores, drops, pool_convs], {input_x: x_test_batch, dropout_keep_prob: 1.0})
            
            #flatten arrays            
            #batch_embeddings_flat = batch_embeddings.reshape(batch_embeddings.shape[0],-1)
            #print("embeddings size:",  batch_embeddings_flat.shape)
            batch_scores_flat = batch_scores.reshape(batch_scores.shape[0],-1)
            #print("scores size:",  batch_scores_flat.shape)
            batch_pool_convs_flat = batch_pool_convs.reshape(batch_pool_convs.shape[0],-1)
            #print("pool_convs size:",  batch_pool_convs_flat.shape)
            #batch_embeddings_flat = batch_embeddings.reshape(batch_embeddings.shape[0],-1)
            batch_drops_flat = batch_drops.reshape(batch_drops.shape[0],-1)
            
            #Padding
            print(batch_scores_flat.shape[1], batch_pool_convs_flat.shape[1], batch_drops_flat.shape[1])
            
            padding_size = max(batch_scores_flat.shape[1], batch_pool_convs_flat.shape[1], batch_drops_flat.shape[1])
            padding_size = max(batch_scores_flat.shape[1], batch_pool_convs_flat.shape[1], batch_drops_flat.shape[1])
            
            padding = np.zeros((FLAGS.batch_size, padding_size))
            pool_conv_padded = padding
            pool_conv_padded[0:batch_pool_convs_flat.shape[0],0:batch_pool_convs_flat.shape[1]] = batch_pool_convs_flat
            scores_padded = padding
            scores_padded[0:batch_scores_flat.shape[0],0:batch_scores_flat.shape[1]] = batch_scores_flat
            drops_padded = padding
            drops_padded[0:batch_drops.shape[0],0:batch_drops.shape[1]] = batch_drops
            
            #Write to batch file .csv
            time_str = datetime.datetime.now().isoformat()
            file_name = "output_data" + time_str + ".csv"
            out_file_path = os.path.join(out_dir, file_name)
            data = np.hstack((pool_conv_padded, drops_padded, scores_padded))
            print(data.shape)
            #pd_data = pd.DataFrame.from_records(data, columns=["embeddings", "pool_conv", "scores"])
            #data_dict = {'embeddings': batch_embeddings_flat,'pool_convs': pool_conv_padded,
            #                                      'scores': scores_padded}
            #pd_data= pd.DataFrame.from_dict(data_dict)
            
            #pd_data.to_csv(path_or_buf=out_file_path, sep=',', float_format=None, header=True, index=True, 
            #               mode='w', line_terminator='\n')
            np.savetxt(out_file_path, data, delimiter=',')
            
            all_predictions = np.concatenate([all_predictions, batch_predictions])
            probabilities = softmax(batch_scores)
            
            if all_probabilities is not None:
                all_probabilities = np.concatenate([all_probabilities, probabilities])
            else:
                all_probabilities = probabilities
# Out:
# Evaluating...
#
# INFO:tensorflow:Restoring parameters from /root/My_Text_Classification_v3/runs/1548728574/checkpoints/model-4500
# input_x
# input_y
# dropout_keep_prob
# Placeholder
# Const
# embedding/random_uniform/shape
# embedding/random_uniform/min
# embedding/random_uniform/max
# embedding/random_uniform/RandomUniform
# embedding/random_uniform/sub
# embedding/random_uniform/mul
# embedding/random_uniform
# embedding/W
# embedding/W/Assign
# embedding/W/read
# embedding/embedded_chars/axis
# embedding/embedded_chars
# embedding/ExpandDims/dim
# embedding/ExpandDims
# conv-maxpool-3/truncated_normal/shape
# conv-maxpool-3/truncated_normal/mean
# conv-maxpool-3/truncated_normal/stddev
# conv-maxpool-3/truncated_normal/TruncatedNormal
# conv-maxpool-3/truncated_normal/mul
# conv-maxpool-3/truncated_normal
# conv-maxpool-3/filter_matrix
# conv-maxpool-3/filter_matrix/Assign
# conv-maxpool-3/filter_matrix/read
# conv-maxpool-3/Const
# conv-maxpool-3/b
# conv-maxpool-3/b/Assign
# conv-maxpool-3/b/read
# conv-maxpool-3/conv
# conv-maxpool-3/BiasAdd
# conv-maxpool-3/relu
# conv-maxpool-3/pool
# conv-maxpool-4/truncated_normal/shape
# conv-maxpool-4/truncated_normal/mean
# conv-maxpool-4/truncated_normal/stddev
# conv-maxpool-4/truncated_normal/TruncatedNormal
# conv-maxpool-4/truncated_normal/mul
# conv-maxpool-4/truncated_normal
# conv-maxpool-4/filter_matrix
# conv-maxpool-4/filter_matrix/Assign
# conv-maxpool-4/filter_matrix/read
# conv-maxpool-4/Const
# conv-maxpool-4/b
# conv-maxpool-4/b/Assign
# conv-maxpool-4/b/read
# conv-maxpool-4/conv
# conv-maxpool-4/BiasAdd
# conv-maxpool-4/relu
# conv-maxpool-4/pool
# conv-maxpool-5/truncated_normal/shape
# conv-maxpool-5/truncated_normal/mean
# conv-maxpool-5/truncated_normal/stddev
# conv-maxpool-5/truncated_normal/TruncatedNormal
# conv-maxpool-5/truncated_normal/mul
# conv-maxpool-5/truncated_normal
# conv-maxpool-5/filter_matrix
# conv-maxpool-5/filter_matrix/Assign
# conv-maxpool-5/filter_matrix/read
# conv-maxpool-5/Const
# conv-maxpool-5/b
# conv-maxpool-5/b/Assign
# conv-maxpool-5/b/read
# conv-maxpool-5/conv
# conv-maxpool-5/BiasAdd
# conv-maxpool-5/relu
# conv-maxpool-5/pool
# pool/concat/axis
# pool/concat
# pool/h_pool_flat/shape
# pool/h_pool_flat
# dropout/h_drop/Shape
# dropout/h_drop/random_uniform/min
# dropout/h_drop/random_uniform/max
# dropout/h_drop/random_uniform/RandomUniform
# dropout/h_drop/random_uniform/sub
# dropout/h_drop/random_uniform/mul
# dropout/h_drop/random_uniform
# dropout/h_drop/add
# dropout/h_drop/Floor
# dropout/h_drop/div
# dropout/h_drop/mul
# W/Initializer/random_uniform/shape
# W/Initializer/random_uniform/min
# W/Initializer/random_uniform/max
# W/Initializer/random_uniform/RandomUniform
# W/Initializer/random_uniform/sub
# W/Initializer/random_uniform/mul
# W/Initializer/random_uniform
# W
# W/Assign
# W/read
# output/Const
# output/b
# output/b/Assign
# output/b/read
# output/L2Loss
# output/add
# output/L2Loss_1
# output/add_1
# output/scores/MatMul
# output/scores
# output/predictions/dimension
# output/predictions
# loss/softmax_cross_entropy_with_logits_sg/labels_stop_gradient
# loss/softmax_cross_entropy_with_logits_sg/Rank
# loss/softmax_cross_entropy_with_logits_sg/Shape
# loss/softmax_cross_entropy_with_logits_sg/Rank_1
# loss/softmax_cross_entropy_with_logits_sg/Shape_1
# loss/softmax_cross_entropy_with_logits_sg/Sub/y
# loss/softmax_cross_entropy_with_logits_sg/Sub
# loss/softmax_cross_entropy_with_logits_sg/Slice/begin
# loss/softmax_cross_entropy_with_logits_sg/Slice/size
# loss/softmax_cross_entropy_with_logits_sg/Slice
# loss/softmax_cross_entropy_with_logits_sg/concat/values_0
# loss/softmax_cross_entropy_with_logits_sg/concat/axis
# loss/softmax_cross_entropy_with_logits_sg/concat
# loss/softmax_cross_entropy_with_logits_sg/Reshape
# loss/softmax_cross_entropy_with_logits_sg/Rank_2
# loss/softmax_cross_entropy_with_logits_sg/Shape_2
# loss/softmax_cross_entropy_with_logits_sg/Sub_1/y
# loss/softmax_cross_entropy_with_logits_sg/Sub_1
# loss/softmax_cross_entropy_with_logits_sg/Slice_1/begin
# loss/softmax_cross_entropy_with_logits_sg/Slice_1/size
# loss/softmax_cross_entropy_with_logits_sg/Slice_1
# loss/softmax_cross_entropy_with_logits_sg/concat_1/values_0
# loss/softmax_cross_entropy_with_logits_sg/concat_1/axis
# loss/softmax_cross_entropy_with_logits_sg/concat_1
# loss/softmax_cross_entropy_with_logits_sg/Reshape_1
# loss/softmax_cross_entropy_with_logits_sg
# loss/softmax_cross_entropy_with_logits_sg/Sub_2/y
# loss/softmax_cross_entropy_with_logits_sg/Sub_2
# loss/softmax_cross_entropy_with_logits_sg/Slice_2/begin
# loss/softmax_cross_entropy_with_logits_sg/Slice_2/size
# loss/softmax_cross_entropy_with_logits_sg/Slice_2
# loss/softmax_cross_entropy_with_logits_sg/Reshape_2
# loss/Const
# loss/Mean
# loss/mul/x
# loss/mul
# loss/add
# accuracy/ArgMax/dimension
# accuracy/ArgMax
# accuracy/Equal
# accuracy/Cast
# accuracy/Const
# accuracy/accuracy
# global_step/initial_value
# global_step
# global_step/Assign
# global_step/read
# gradients/Shape
# gradients/grad_ys_0
# gradients/Fill
# gradients/loss/add_grad/tuple/group_deps
# gradients/loss/add_grad/tuple/control_dependency
# gradients/loss/add_grad/tuple/control_dependency_1
# gradients/loss/Mean_grad/Reshape/shape
# gradients/loss/Mean_grad/Reshape
# gradients/loss/Mean_grad/Shape
# gradients/loss/Mean_grad/Tile
# gradients/loss/Mean_grad/Shape_1
# gradients/loss/Mean_grad/Shape_2
# gradients/loss/Mean_grad/Const
# gradients/loss/Mean_grad/Prod
# gradients/loss/Mean_grad/Const_1
# gradients/loss/Mean_grad/Prod_1
# gradients/loss/Mean_grad/Maximum/y
# gradients/loss/Mean_grad/Maximum
# gradients/loss/Mean_grad/floordiv
# gradients/loss/Mean_grad/Cast
# gradients/loss/Mean_grad/truediv
# gradients/loss/mul_grad/Mul
# gradients/loss/mul_grad/Mul_1
# gradients/loss/mul_grad/tuple/group_deps
# gradients/loss/mul_grad/tuple/control_dependency
# gradients/loss/mul_grad/tuple/control_dependency_1
# gradients/loss/softmax_cross_entropy_with_logits_sg/Reshape_2_grad/Shape
# gradients/loss/softmax_cross_entropy_with_logits_sg/Reshape_2_grad/Reshape
# gradients/output/add_1_grad/tuple/group_deps
# gradients/output/add_1_grad/tuple/control_dependency
# gradients/output/add_1_grad/tuple/control_dependency_1
# gradients/zeros_like
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/ExpandDims/dim
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/ExpandDims
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/mul
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/LogSoftmax
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/Neg
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/ExpandDims_1/dim
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/ExpandDims_1
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/mul_1
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/tuple/group_deps
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/tuple/control_dependency
# gradients/loss/softmax_cross_entropy_with_logits_sg_grad/tuple/control_dependency_1
# gradients/output/add_grad/tuple/group_deps
# gradients/output/add_grad/tuple/control_dependency
# gradients/output/add_grad/tuple/control_dependency_1
# gradients/output/L2Loss_1_grad/mul
# gradients/loss/softmax_cross_entropy_with_logits_sg/Reshape_grad/Shape
# gradients/loss/softmax_cross_entropy_with_logits_sg/Reshape_grad/Reshape
# gradients/output/L2Loss_grad/mul
# gradients/output/scores_grad/BiasAddGrad
# gradients/output/scores_grad/tuple/group_deps
# gradients/output/scores_grad/tuple/control_dependency
# gradients/output/scores_grad/tuple/control_dependency_1
# gradients/output/scores/MatMul_grad/MatMul
# gradients/output/scores/MatMul_grad/MatMul_1
# gradients/output/scores/MatMul_grad/tuple/group_deps
# gradients/output/scores/MatMul_grad/tuple/control_dependency
# gradients/output/scores/MatMul_grad/tuple/control_dependency_1
# gradients/AddN
# gradients/dropout/h_drop/mul_grad/Shape
# gradients/dropout/h_drop/mul_grad/Shape_1
# gradients/dropout/h_drop/mul_grad/BroadcastGradientArgs
# gradients/dropout/h_drop/mul_grad/Mul
# gradients/dropout/h_drop/mul_grad/Sum
# gradients/dropout/h_drop/mul_grad/Reshape
# gradients/dropout/h_drop/mul_grad/Mul_1
# gradients/dropout/h_drop/mul_grad/Sum_1
# gradients/dropout/h_drop/mul_grad/Reshape_1
# gradients/dropout/h_drop/mul_grad/tuple/group_deps
# gradients/dropout/h_drop/mul_grad/tuple/control_dependency
# gradients/dropout/h_drop/mul_grad/tuple/control_dependency_1
# gradients/AddN_1
# gradients/dropout/h_drop/div_grad/Shape
# gradients/dropout/h_drop/div_grad/Shape_1
# gradients/dropout/h_drop/div_grad/BroadcastGradientArgs
# gradients/dropout/h_drop/div_grad/RealDiv
# gradients/dropout/h_drop/div_grad/Sum
# gradients/dropout/h_drop/div_grad/Reshape
# gradients/dropout/h_drop/div_grad/Neg
# gradients/dropout/h_drop/div_grad/RealDiv_1
# gradients/dropout/h_drop/div_grad/RealDiv_2
# gradients/dropout/h_drop/div_grad/mul
# gradients/dropout/h_drop/div_grad/Sum_1
# gradients/dropout/h_drop/div_grad/Reshape_1
# gradients/dropout/h_drop/div_grad/tuple/group_deps
# gradients/dropout/h_drop/div_grad/tuple/control_dependency
# gradients/dropout/h_drop/div_grad/tuple/control_dependency_1
# gradients/pool/h_pool_flat_grad/Shape
# gradients/pool/h_pool_flat_grad/Reshape
# gradients/pool/concat_grad/Rank
# gradients/pool/concat_grad/mod
# gradients/pool/concat_grad/Shape
# gradients/pool/concat_grad/ShapeN
# gradients/pool/concat_grad/ConcatOffset
# gradients/pool/concat_grad/Slice
# gradients/pool/concat_grad/Slice_1
# gradients/pool/concat_grad/Slice_2
# gradients/pool/concat_grad/tuple/group_deps
# gradients/pool/concat_grad/tuple/control_dependency
# gradients/pool/concat_grad/tuple/control_dependency_1
# gradients/pool/concat_grad/tuple/control_dependency_2
# gradients/conv-maxpool-3/pool_grad/MaxPoolGrad
# gradients/conv-maxpool-4/pool_grad/MaxPoolGrad
# gradients/conv-maxpool-5/pool_grad/MaxPoolGrad
# gradients/conv-maxpool-3/relu_grad/ReluGrad
# gradients/conv-maxpool-4/relu_grad/ReluGrad
# gradients/conv-maxpool-5/relu_grad/ReluGrad
# gradients/conv-maxpool-3/BiasAdd_grad/BiasAddGrad
# gradients/conv-maxpool-3/BiasAdd_grad/tuple/group_deps
# gradients/conv-maxpool-3/BiasAdd_grad/tuple/control_dependency
# gradients/conv-maxpool-3/BiasAdd_grad/tuple/control_dependency_1
# gradients/conv-maxpool-4/BiasAdd_grad/BiasAddGrad
# gradients/conv-maxpool-4/BiasAdd_grad/tuple/group_deps
# gradients/conv-maxpool-4/BiasAdd_grad/tuple/control_dependency
# gradients/conv-maxpool-4/BiasAdd_grad/tuple/control_dependency_1
# gradients/conv-maxpool-5/BiasAdd_grad/BiasAddGrad
# gradients/conv-maxpool-5/BiasAdd_grad/tuple/group_deps
# gradients/conv-maxpool-5/BiasAdd_grad/tuple/control_dependency
# gradients/conv-maxpool-5/BiasAdd_grad/tuple/control_dependency_1
# gradients/conv-maxpool-3/conv_grad/ShapeN
# gradients/conv-maxpool-3/conv_grad/Conv2DBackpropInput
# gradients/conv-maxpool-3/conv_grad/Conv2DBackpropFilter
# gradients/conv-maxpool-3/conv_grad/tuple/group_deps
# gradients/conv-maxpool-3/conv_grad/tuple/control_dependency
# gradients/conv-maxpool-3/conv_grad/tuple/control_dependency_1
# gradients/conv-maxpool-4/conv_grad/ShapeN
# gradients/conv-maxpool-4/conv_grad/Conv2DBackpropInput
# gradients/conv-maxpool-4/conv_grad/Conv2DBackpropFilter
# gradients/conv-maxpool-4/conv_grad/tuple/group_deps
# gradients/conv-maxpool-4/conv_grad/tuple/control_dependency
# gradients/conv-maxpool-4/conv_grad/tuple/control_dependency_1
# gradients/conv-maxpool-5/conv_grad/ShapeN
# gradients/conv-maxpool-5/conv_grad/Conv2DBackpropInput
# gradients/conv-maxpool-5/conv_grad/Conv2DBackpropFilter
# gradients/conv-maxpool-5/conv_grad/tuple/group_deps
# gradients/conv-maxpool-5/conv_grad/tuple/control_dependency
# gradients/conv-maxpool-5/conv_grad/tuple/control_dependency_1
# gradients/AddN_2
# gradients/embedding/ExpandDims_grad/Shape
# gradients/embedding/ExpandDims_grad/Reshape
# gradients/embedding/embedded_chars_grad/Shape
# gradients/embedding/embedded_chars_grad/ToInt32
# gradients/embedding/embedded_chars_grad/Size
# gradients/embedding/embedded_chars_grad/ExpandDims/dim
# gradients/embedding/embedded_chars_grad/ExpandDims
# gradients/embedding/embedded_chars_grad/strided_slice/stack
# gradients/embedding/embedded_chars_grad/strided_slice/stack_1
# gradients/embedding/embedded_chars_grad/strided_slice/stack_2
# gradients/embedding/embedded_chars_grad/strided_slice
# gradients/embedding/embedded_chars_grad/concat/axis
# gradients/embedding/embedded_chars_grad/concat
# gradients/embedding/embedded_chars_grad/Reshape
# gradients/embedding/embedded_chars_grad/Reshape_1
# beta1_power/initial_value
# beta1_power
# beta1_power/Assign
# beta1_power/read
# beta2_power/initial_value
# beta2_power
# beta2_power/Assign
# beta2_power/read
# embedding/W/Adam/Initializer/zeros/shape_as_tensor
# embedding/W/Adam/Initializer/zeros/Const
# embedding/W/Adam/Initializer/zeros
# embedding/W/Adam
# embedding/W/Adam/Assign
# embedding/W/Adam/read
# embedding/W/Adam_1/Initializer/zeros/shape_as_tensor
# embedding/W/Adam_1/Initializer/zeros/Const
# embedding/W/Adam_1/Initializer/zeros
# embedding/W/Adam_1
# embedding/W/Adam_1/Assign
# embedding/W/Adam_1/read
# conv-maxpool-3/filter_matrix/Adam/Initializer/zeros/shape_as_tensor
# conv-maxpool-3/filter_matrix/Adam/Initializer/zeros/Const
# conv-maxpool-3/filter_matrix/Adam/Initializer/zeros
# conv-maxpool-3/filter_matrix/Adam
# conv-maxpool-3/filter_matrix/Adam/Assign
# conv-maxpool-3/filter_matrix/Adam/read
# conv-maxpool-3/filter_matrix/Adam_1/Initializer/zeros/shape_as_tensor
# conv-maxpool-3/filter_matrix/Adam_1/Initializer/zeros/Const
# conv-maxpool-3/filter_matrix/Adam_1/Initializer/zeros
# conv-maxpool-3/filter_matrix/Adam_1
# conv-maxpool-3/filter_matrix/Adam_1/Assign
# conv-maxpool-3/filter_matrix/Adam_1/read
# conv-maxpool-3/b/Adam/Initializer/zeros
# conv-maxpool-3/b/Adam
# conv-maxpool-3/b/Adam/Assign
# conv-maxpool-3/b/Adam/read
# conv-maxpool-3/b/Adam_1/Initializer/zeros
# conv-maxpool-3/b/Adam_1
# conv-maxpool-3/b/Adam_1/Assign
# conv-maxpool-3/b/Adam_1/read
# conv-maxpool-4/filter_matrix/Adam/Initializer/zeros/shape_as_tensor
# conv-maxpool-4/filter_matrix/Adam/Initializer/zeros/Const
# conv-maxpool-4/filter_matrix/Adam/Initializer/zeros
# conv-maxpool-4/filter_matrix/Adam
# conv-maxpool-4/filter_matrix/Adam/Assign
# conv-maxpool-4/filter_matrix/Adam/read
# conv-maxpool-4/filter_matrix/Adam_1/Initializer/zeros/shape_as_tensor
# conv-maxpool-4/filter_matrix/Adam_1/Initializer/zeros/Const
# conv-maxpool-4/filter_matrix/Adam_1/Initializer/zeros
# conv-maxpool-4/filter_matrix/Adam_1
# conv-maxpool-4/filter_matrix/Adam_1/Assign
# conv-maxpool-4/filter_matrix/Adam_1/read
# conv-maxpool-4/b/Adam/Initializer/zeros
# conv-maxpool-4/b/Adam
# conv-maxpool-4/b/Adam/Assign
# conv-maxpool-4/b/Adam/read
# conv-maxpool-4/b/Adam_1/Initializer/zeros
# conv-maxpool-4/b/Adam_1
# conv-maxpool-4/b/Adam_1/Assign
# conv-maxpool-4/b/Adam_1/read
# conv-maxpool-5/filter_matrix/Adam/Initializer/zeros/shape_as_tensor
# conv-maxpool-5/filter_matrix/Adam/Initializer/zeros/Const
# conv-maxpool-5/filter_matrix/Adam/Initializer/zeros
# conv-maxpool-5/filter_matrix/Adam
# conv-maxpool-5/filter_matrix/Adam/Assign
# conv-maxpool-5/filter_matrix/Adam/read
# conv-maxpool-5/filter_matrix/Adam_1/Initializer/zeros/shape_as_tensor
# conv-maxpool-5/filter_matrix/Adam_1/Initializer/zeros/Const
# conv-maxpool-5/filter_matrix/Adam_1/Initializer/zeros
# conv-maxpool-5/filter_matrix/Adam_1
# conv-maxpool-5/filter_matrix/Adam_1/Assign
# conv-maxpool-5/filter_matrix/Adam_1/read
# conv-maxpool-5/b/Adam/Initializer/zeros
# conv-maxpool-5/b/Adam
# conv-maxpool-5/b/Adam/Assign
# conv-maxpool-5/b/Adam/read
# conv-maxpool-5/b/Adam_1/Initializer/zeros
# conv-maxpool-5/b/Adam_1
# conv-maxpool-5/b/Adam_1/Assign
# conv-maxpool-5/b/Adam_1/read
# W/Adam/Initializer/zeros
# W/Adam
# W/Adam/Assign
# W/Adam/read
# W/Adam_1/Initializer/zeros
# W/Adam_1
# W/Adam_1/Assign
# W/Adam_1/read
# output/b/Adam/Initializer/zeros
# output/b/Adam
# output/b/Adam/Assign
# output/b/Adam/read
# output/b/Adam_1/Initializer/zeros
# output/b/Adam_1
# output/b/Adam_1/Assign
# output/b/Adam_1/read
# Adam/beta1
# Adam/beta2
# Adam/epsilon
# Adam/update_embedding/W/Unique
# Adam/update_embedding/W/Shape
# Adam/update_embedding/W/strided_slice/stack
# Adam/update_embedding/W/strided_slice/stack_1
# Adam/update_embedding/W/strided_slice/stack_2
# Adam/update_embedding/W/strided_slice
# Adam/update_embedding/W/UnsortedSegmentSum
# Adam/update_embedding/W/sub/x
# Adam/update_embedding/W/sub
# Adam/update_embedding/W/Sqrt
# Adam/update_embedding/W/mul
# Adam/update_embedding/W/sub_1/x
# Adam/update_embedding/W/sub_1
# Adam/update_embedding/W/truediv
# Adam/update_embedding/W/sub_2/x
# Adam/update_embedding/W/sub_2
# Adam/update_embedding/W/mul_1
# Adam/update_embedding/W/mul_2
# Adam/update_embedding/W/Assign
# Adam/update_embedding/W/ScatterAdd
# Adam/update_embedding/W/mul_3
# Adam/update_embedding/W/sub_3/x
# Adam/update_embedding/W/sub_3
# Adam/update_embedding/W/mul_4
# Adam/update_embedding/W/mul_5
# Adam/update_embedding/W/Assign_1
# Adam/update_embedding/W/ScatterAdd_1
# Adam/update_embedding/W/Sqrt_1
# Adam/update_embedding/W/mul_6
# Adam/update_embedding/W/add
# Adam/update_embedding/W/truediv_1
# Adam/update_embedding/W/AssignSub
# Adam/update_embedding/W/group_deps
# Adam/update_conv-maxpool-3/filter_matrix/ApplyAdam
# Adam/update_conv-maxpool-3/b/ApplyAdam
# Adam/update_conv-maxpool-4/filter_matrix/ApplyAdam
# Adam/update_conv-maxpool-4/b/ApplyAdam
# Adam/update_conv-maxpool-5/filter_matrix/ApplyAdam
# Adam/update_conv-maxpool-5/b/ApplyAdam
# Adam/update_W/ApplyAdam
# Adam/update_output/b/ApplyAdam
# Adam/mul
# Adam/Assign
# Adam/mul_1
# Adam/Assign_1
# Adam/update
# Adam/value
# Adam
# embedding/W_0/grad/hist/tag
# embedding/W_0/grad/hist/strided_slice/stack
# embedding/W_0/grad/hist/strided_slice/stack_1
# embedding/W_0/grad/hist/strided_slice/stack_2
# embedding/W_0/grad/hist/strided_slice
# embedding/W_0/grad/hist/values
# embedding/W_0/grad/hist
# zero_fraction/strided_slice/stack
# zero_fraction/strided_slice/stack_1
# zero_fraction/strided_slice/stack_2
# zero_fraction/strided_slice
# zero_fraction/value
# zero_fraction/zero
# zero_fraction/Equal
# zero_fraction/Cast
# zero_fraction/Const
# zero_fraction/Mean
# embedding/W_0/grad/sparsity/tags
# embedding/W_0/grad/sparsity
# conv-maxpool-3/filter_matrix_0/grad/hist/tag
# conv-maxpool-3/filter_matrix_0/grad/hist
# zero_fraction_1/zero
# zero_fraction_1/Equal
# zero_fraction_1/Cast
# zero_fraction_1/Const
# zero_fraction_1/Mean
# conv-maxpool-3/filter_matrix_0/grad/sparsity/tags
# conv-maxpool-3/filter_matrix_0/grad/sparsity
# conv-maxpool-3/b_0/grad/hist/tag
# conv-maxpool-3/b_0/grad/hist
# zero_fraction_2/zero
# zero_fraction_2/Equal
# zero_fraction_2/Cast
# zero_fraction_2/Const
# zero_fraction_2/Mean
# conv-maxpool-3/b_0/grad/sparsity/tags
# conv-maxpool-3/b_0/grad/sparsity
# conv-maxpool-4/filter_matrix_0/grad/hist/tag
# conv-maxpool-4/filter_matrix_0/grad/hist
# zero_fraction_3/zero
# zero_fraction_3/Equal
# zero_fraction_3/Cast
# zero_fraction_3/Const
# zero_fraction_3/Mean
# conv-maxpool-4/filter_matrix_0/grad/sparsity/tags
# conv-maxpool-4/filter_matrix_0/grad/sparsity
# conv-maxpool-4/b_0/grad/hist/tag
# conv-maxpool-4/b_0/grad/hist
# zero_fraction_4/zero
# zero_fraction_4/Equal
# zero_fraction_4/Cast
# zero_fraction_4/Const
# zero_fraction_4/Mean
# conv-maxpool-4/b_0/grad/sparsity/tags
# conv-maxpool-4/b_0/grad/sparsity
# conv-maxpool-5/filter_matrix_0/grad/hist/tag
# conv-maxpool-5/filter_matrix_0/grad/hist
# zero_fraction_5/zero
# zero_fraction_5/Equal
# zero_fraction_5/Cast
# zero_fraction_5/Const
# zero_fraction_5/Mean
# conv-maxpool-5/filter_matrix_0/grad/sparsity/tags
# conv-maxpool-5/filter_matrix_0/grad/sparsity
# conv-maxpool-5/b_0/grad/hist/tag
# conv-maxpool-5/b_0/grad/hist
# zero_fraction_6/zero
# zero_fraction_6/Equal
# zero_fraction_6/Cast
# zero_fraction_6/Const
# zero_fraction_6/Mean
# conv-maxpool-5/b_0/grad/sparsity/tags
# conv-maxpool-5/b_0/grad/sparsity
# W_0/grad/hist/tag
# W_0/grad/hist
# zero_fraction_7/zero
# zero_fraction_7/Equal
# zero_fraction_7/Cast
# zero_fraction_7/Const
# zero_fraction_7/Mean
# W_0/grad/sparsity/tags
# W_0/grad/sparsity
# output/b_0/grad/hist/tag
# output/b_0/grad/hist
# zero_fraction_8/zero
# zero_fraction_8/Equal
# zero_fraction_8/Cast
# zero_fraction_8/Const
# zero_fraction_8/Mean
# output/b_0/grad/sparsity/tags
# output/b_0/grad/sparsity
# Merge/MergeSummary
# loss_1/tags
# loss_1
# accuracy_1/tags
# accuracy_1
# Merge_1/MergeSummary
# Merge_2/MergeSummary
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/Assign_1
# save/Assign_2
# save/Assign_3
# save/Assign_4
# save/Assign_5
# save/Assign_6
# save/Assign_7
# save/Assign_8
# save/Assign_9
# save/Assign_10
# save/Assign_11
# save/Assign_12
# save/Assign_13
# save/Assign_14
# save/Assign_15
# save/Assign_16
# save/Assign_17
# save/Assign_18
# save/Assign_19
# save/Assign_20
# save/Assign_21
# save/Assign_22
# save/Assign_23
# save/Assign_24
# save/Assign_25
# save/Assign_26
# save/Assign_27
# save/Assign_28
# save/Assign_29
# save/restore_all
# init
# Assign/value
# Assign
# Ready for the run...
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)
# 2 384 384
# (64, 1152)

# %%
print(len(data_out))
# Out:
# 64

# %%
# Print accuracy if y_test is defined
if y_test is not None:
    correct_predictions = float(sum(all_predictions == y_test))
    print("Total number of test examples: {}".format(len(y_test)))
    print("Accuracy: {:g}".format(correct_predictions/float(len(y_test))))
    print(metrics.classification_report(y_test, all_predictions, target_names=datasets['target_names']))
    print(metrics.confusion_matrix(y_test, all_predictions))

# Save the evaluation to a csv
# predictions_human_readable = np.column_stack((np.array(x_raw), all_predictions))
predictions_human_readable = np.column_stack((np.array(x_raw),
                                              [int(prediction) for prediction in all_predictions],
                                              [ "{}".format(probability) for probability in all_probabilities]))
out_path = os.path.join(FLAGS.checkpoint_dir, "..", "prediction.csv")
print("Saving evaluation to {0}".format(out_path))
with open(out_path, 'w') as f:
    csv.writer(f).writerows(predictions_human_readable)
# Out:
# Total number of test examples: 10662
# Accuracy: 0.973082
#                    precision    recall  f1-score   support
#
# positive_examples       0.97      0.98      0.97      5331
# negative_examples       0.98      0.97      0.97      5331
#
#       avg / total       0.97      0.97      0.97     10662
#
# [[5201  130]
#  [ 157 5174]]
# Saving evaluation to ./runs/1548728574/checkpoints/../prediction.csv
